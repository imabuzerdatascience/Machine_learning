# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("dataset.csv")
df.tail()
# Out:
#            f1        f2        f3        f4        f5        f6        f7  \
# 195  1.146487 -0.339530 -2.508957  0.252195 -0.384182  0.184859 -0.770425
# 196 -0.357029 -1.091701  0.534506 -2.153343  1.051948 -0.526035  0.420973
# 197  0.099314  0.023081 -2.367478  0.309727 -0.220018 -1.680870  0.395599
# 198 -0.051119  0.030476 -0.111319  0.520689  0.257253  0.466431 -0.702911
# 199 -0.592464 -0.562168  0.288694 -0.088363 -0.646227 -0.109610  0.006422
#
#            f8        f9       f10  ...      f142      f143      f144  \
# 195  0.613266 -1.112327 -0.166815  ... -0.960417  1.565103  0.500333
# 196  1.995667  0.890383  0.497743  ...  0.138976  0.417681  0.093365
# 197  0.633225 -0.390409 -0.948749  ... -0.519942  1.021659  0.059655
# 198 -0.545087  0.016125 -2.707544  ... -2.205935 -0.733608 -0.725518
# 199  1.000582 -0.026406 -1.748532  ... -0.468661  0.888839  0.902492
#
#          f145      f146      f147      f148      f149      f150      target
# 195 -0.774601 -0.993825  0.307204  0.044206  0.832110  0.546968  -18.681830
# 196 -0.659427  0.004001 -0.714387 -0.780377 -0.336150 -0.119423  234.589644
# 197 -0.163061  0.756115 -0.531876 -0.286706  0.670167 -0.031396  -94.329646
# 198  1.187127 -1.113844  0.226657 -0.128128  1.043043  0.595832   80.152034
# 199  0.952591  0.387827  1.377367  0.378354  1.713530 -1.619920  110.131842
#
# [5 rows x 151 columns]

# %%
x = df.drop(["target"] , axis=1)
y = df["target"]

# %%
y[:5]
# Out:
# 0     10.681366
# 1    -60.163343
# 2    131.226545
# 3   -131.889020
# 4   -138.566956
# Name: target, dtype: float64

# %%
# using train test split method 
X_train , X_test , Y_train , Y_test = train_test_split(x , y , test_size = 0.2 , random_state=42)

# %%
### using simple linear regression 
model = LinearRegression()
model.fit(X_train , Y_train)
model.score(X_test , Y_test)
# Out:
# 0.8656382496943851

# %% [markdown]
# ### Training Using Lasso Regression Model (L1 Regularization)

# %%
lasso_model = Lasso(alpha=1)
lasso_model.fit(X_train , Y_train)
lasso_model.score(X_test , Y_test )
# Out:
# 0.9905099255716072

# %% [markdown]
# ### Training Using Ridge Regression Model (L2 Regularization)

# %%
Ridge_model = Ridge(alpha=1)
Ridge_model.fit(X_train , Y_train)
Ridge_model.score(X_test , Y_test )
# Out:
# 0.9353857731012797
